# %% [markdown]
# # Google Colab Workspace
#
#
# - Provides free access to GPI and TPUs.
# - Provides collaborative working opportunities.

# %% [markdown]
# ## About GPU

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2299.998
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4599.99
# clflush size	: 64
# cache_alignment	: 64
# ...

# %% [markdown]
# ## About RAM

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13302920 kB
# MemFree:         9291200 kB
# MemAvailable:   12120224 kB
# Buffers:          140112 kB
# Cached:          2767000 kB
# SwapCached:            0 kB
# Active:          1636680 kB
# Inactive:        2092064 kB
# Active(anon):     723564 kB
# Inactive(anon):      460 kB
# Active(file):     913116 kB
# Inactive(file):  2091604 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               444 kB
# Writeback:             0 kB
# AnonPages:        821772 kB
# Mapped:           264552 kB
# Shmem:              1204 kB
# KReclaimable:     131556 kB
# Slab:             180692 kB
# SReclaimable:     131556 kB
# SUnreclaim:        49136 kB
# KernelStack:        4912 kB
# PageTables:        11600 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6651460 kB
# Committed_AS:    3206208 kB
# VmallocTotal:   34359738367 kB
# ...

# %% [markdown]
# # Data Science
#
# For data science, we can also perform analysis and visualization processes by using different libraries of `Python` in the Colab environment.

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 50 + np.random.randn(50)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '*')
plt.fill_between(x, ys, 45, where = (ys > 45), facecolor = "m", alpha = 0.5)

plt.title("Example")
plt.show()

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x=alt.X('Miles_per_Gallon', bin=True),
  y='count()',
  color='Origin'
)
# Out:
# alt.Chart(...)

# %%
from vega_datasets import data
stocks = data.stocks()

import altair as alt
alt.Chart(stocks).mark_line().encode(
  x='date:T',
  y='price',
  color='symbol'
).interactive(bind_y=False)
# Out:
# alt.Chart(...)

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
# !ls
# to see files
# Out:
# MyDrive  Othercomputers

# %%
# !ls "/gdrive/My Drive/calisma_ortamı"
# Out:
# colab_calisma_ortamı.ipynb

# %%
import os
os.chdir("/gdrive/My Drive/calisma_ortamı")

# %%
# !ls
# Out:
# colab_calisma_ortamı.ipynb

# %% [markdown]
# ## Library Install

# %%
# !pip install -q keras

# %%
import keras

# %%
# !apt-get install graphviz -y

# %% [markdown]
# ## Viewing GPU Properties

# %% [markdown]
# runtime type: none

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
import tensorflow_hub as hub
# when import tensorflow every time the last version come
# if want to chose spesific version need to type

# %%
print("TF version: ", tf.__version__)
print("Hub version:", hub.__version__)
print("GPU is","available" if tf.test.is_gpu_available() else " not available")
# Out:
# TF version:  2.7.0
# Hub version: 0.12.0
# WARNING:tensorflow:From <ipython-input-17-f75c2e0936fe>:3: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU is available

# %% [markdown]
# runtime -> change runtime type -> gpu

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
import tensorflow_hub as hub
print("TF version: ", tf.__version__)
print("Hub version:", hub.__version__)
print("GPU is","available" if tf.test.is_gpu_available() else " not available")
# Out:
# TF version:  2.7.0
# Hub version: 0.12.0
# GPU is available

# %%
# which type of gpu using
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 14842134948880107202
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 11320098816
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 11616194973909770973
#  physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
#  xla_global_id: 416903419]

# %%
# !ls
# authentication must be done again
# reason is switching to gpu

# %%
# !kill -9 -1
# restarts all notebook operations.

# %%
# from google.colab import drive
# drive.mount('/gdrive')
# %cd /gdrive

# %%
# reading py file 
# !python3 filename.py
